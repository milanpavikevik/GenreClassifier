# %% [markdown]
# <a href="https://colab.research.google.com/github/milanpavikevik/GenreClassifier/blob/master/Music_genre_classification_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing libraries

# %%
# feature extractoring and preprocessing data
import librosa
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from PIL import Image
import pathlib
import csv

# Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

import warnings
warnings.filterwarnings('ignore')
# %pylab inline
import os
import glob
from tqdm import tqdm
import itertools
import matplotlib.pyplot as plt
import pandas as pd

# Audio
import librosa.display

# Scikit learn
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix                   
from sklearn.utils import shuffle
from sklearn.utils import class_weight

# Keras
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.utils import to_categorical

import warnings
warnings.filterwarnings('ignore', category=FutureWarning)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Connecting to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data read

# %%
INPUT_DIR=f'/content/drive/My Drive/Songs/all_songs/'
genres = ['classical','hip_hop_rap','metal','pop','turbofolk','techno','rock','narodni','jazz']

# %%
dataset = []
for genre in genres:
  directory = INPUT_DIR + genre + '/**'
  for filename in glob.iglob(directory):
    if os.path.exists(filename):
        label = genre
        duration = librosa.get_duration(filename=filename)
        print('label',label,'duration',duration)
        # skip audio smaller than 3 secs
        if duration>=65 and duration <=600:
            slice_size = 5
            initial_offset = 60
            iterations = 3
            print ('song: ',filename,'initial_offset: ',initial_offset,'iterations: ',iterations,'duration: ',duration)
            for i in range(iterations):
                offset = initial_offset + i*(slice_size-1)
                if (label=="classical"):
                    dataset.append({
                        "filename": filename,
                        "label": "classical",
                        "offset": offset
                        })
                elif (label == 'techno'):
                    dataset.append({
                        "filename": filename,
                        "label": "techno",
                        "offset": offset
                        })
                elif (label == 'hip_hop_rap'):
                    dataset.append({
                      "filename": filename,
                      "label": "hip_hop_rap",
                      "offset": offset
                      })
                elif (label == 'metal'):
                    dataset.append({
                      "filename": filename,
                      "label": "metal",
                      "offset": offset
                      })
                elif (label == 'pop'):
                    dataset.append({
                      "filename": filename,
                      "label": "pop",
                      "offset": offset
                      })
                elif (label == 'turbofolk'):
                    dataset.append({
                      "filename": filename,
                      "label": "turbofolk",
                      "offset": offset
                      })
                elif (label == 'narodni'):
                    dataset.append({
                      "filename": filename,
                      "label": "narodni",
                      "offset": offset
                      })
                elif (label == 'jazz'):
                    dataset.append({
                      "filename": filename,
                      "label": "jazz",
                      "offset": offset
                      })
                elif (label == 'rock'):
                    dataset.append({
                      "filename": filename,
                      "label": "rock",
                      "offset": offset
                      })
# Out:
# label classical duration 298.0
# song:  /content/drive/My Drive/Songs/all_songs/classical/Frédéric Chopin - Nocturne Op. 27 No. 1 (Piano Solo).mp3 initial_offset:  60 iterations:  3 duration:  298.0
# label classical duration 177.0
# song:  /content/drive/My Drive/Songs/all_songs/classical/Antonio Vivaldi- The Four Seasons- Summer- Presto.mp3 initial_offset:  60 iterations:  3 duration:  177.0
# label classical duration 263.3
# song:  /content/drive/My Drive/Songs/all_songs/classical/Mussorgsky - Pictures at an Exhibition - The Old Castle.mp3 initial_offset:  60 iterations:  3 duration:  263.3
# label classical duration 324.7
# song:  /content/drive/My Drive/Songs/all_songs/classical/(HD) Beethoven "Sonata Pathétique"- 2nd mvt  Adagio cantabile.mp3 initial_offset:  60 iterations:  3 duration:  324.7
# label classical duration 459.6
# song:  /content/drive/My Drive/Songs/all_songs/classical/Saint-Saëns - Organ Symphony, Finale!!!.mp3 initial_offset:  60 iterations:  3 duration:  459.6
# label classical duration 358.1
# song:  /content/drive/My Drive/Songs/all_songs/classical/Edward Elgar - Pomp And Circumstance, March No.1 In D.mp3 initial_offset:  60 iterations:  3 duration:  358.1
# label classical duration 1268.4
# label classical duration 178.6
# song:  /content/drive/My Drive/Songs/all_songs/classical/Pierre Boulez conducts the Infernal dance from Stravinsky's Firebird.mp3 initial_offset:  60 iterations:  3 duration:  178.6
# label classical duration 580.1
# song:  /content/drive/My Drive/Songs/all_songs/classical/Mussorgsky - Night On Bald Mountain.mp3 initial_offset:  60 iterations:  3 duration:  580.1
# label classical duration 346.4
# song:  /content/drive/My Drive/Songs/all_songs/classical/Prokofiev - Dance of the Knights.mp3 initial_offset:  60 iterations:  3 duration:  346.4
# label classical duration 434.6
# song:  /content/drive/My Drive/Songs/all_songs/classical/Beethoven - 7th Symphony - 2nd movement.mp3 initial_offset:  60 iterations:  3 duration:  434.6
# label classical duration 384.9
# song:  /content/drive/My Drive/Songs/all_songs/classical/DON GIOVANNI -Commendatore- HD 1080.mp3 initial_offset:  60 iterations:  3 duration:  384.9
# label classical duration 131.4
# song:  /content/drive/My Drive/Songs/all_songs/classical/Jean Baptiste Lully (1632-1687) - Marche pour la cérémonie des Turcs.mp3 initial_offset:  60 iterations:  3 duration:  131.4
# label classical duration 285.5
# song:  /content/drive/My Drive/Songs/all_songs/classical/Rachmaninov - Prelude in C Sharp Minor.mp3 initial_offset:  60 iterations:  3 duration:  285.5
# label classical duration 563.0
# song:  /content/drive/My Drive/Songs/all_songs/classical/Antonio Vivaldi - Winter (Full) - The Four Seasons.mp3 initial_offset:  60 iterations:  3 duration:  563.0
# label classical duration 311.0
# song:  /content/drive/My Drive/Songs/all_songs/classical/Chopin - Spring Waltz (Mariage d'Amour) [Please Read Description].mp3 initial_offset:  60 iterations:  3 duration:  311.0
# label classical duration 269.2
# song:  /content/drive/My Drive/Songs/all_songs/classical/Chopin - Nocturne op.9 No.2.mp3 initial_offset:  60 iterations:  3 duration:  269.2
# label classical duration 614.2
# label classical duration 300.1
# song:  /content/drive/My Drive/Songs/all_songs/classical/Richard Wagner - Ride Of The Valkyries.mp3 initial_offset:  60 iterations:  3 duration:  300.1
# label classical duration 898.3
# label classical duration 565.1
# song:  /content/drive/My Drive/Songs/all_songs/classical/Tchaikovsky - Marche Slave.mp3 initial_offset:  60 iterations:  3 duration:  565.1
# label classical duration 564.8
# song:  /content/drive/My Drive/Songs/all_songs/classical/Frédéric Chopin's Piano Sonata No 2 in B flat minor, Funeral March [HD].mp3 initial_offset:  60 iterations:  3 duration:  564.8
# label classical duration 218.0
# song:  /content/drive/My Drive/Songs/all_songs/classical/Chopin : Etude Op.25 no.11 "Winter Wind" (Pollini).mp3 initial_offset:  60 iterations:  3 duration:  218.0
# label classical duration 258.2
# song:  /content/drive/My Drive/Songs/all_songs/classical/Jean-Baptiste Lully - Te Deum.mp3 initial_offset:  60 iterations:  3 duration:  258.2
# label classical duration 502.0
# song:  /content/drive/My Drive/Songs/all_songs/classical/Gymnopedies No.1-3.mp3 initial_offset:  60 iterations:  3 duration:  502.0
# label classical duration 514.1
# song:  /content/drive/My Drive/Songs/all_songs/classical/Beethoven - Coriolan Overture (Karajan & Berliner Philharmoniker).mp3 initial_offset:  60 iterations:  3 duration:  514.1
# label classical duration 234.9
# song:  /content/drive/My Drive/Songs/all_songs/classical/Jean-Baptiste Lully - O sapientia (complete).mp3 initial_offset:  60 iterations:  3 duration:  234.9
# label classical duration 186.1
# song:  /content/drive/My Drive/Songs/all_songs/classical/Lacrimosa (Requiem) - Wolfgang Amadeus Mozart (lyrics).mp3 initial_offset:  60 iterations:  3 duration:  186.1
# label classical duration 4160.2
# label classical duration 1167.8
# label classical duration 469.3
# song:  /content/drive/My Drive/Songs/all_songs/classical/Wolfgang Amadeus Mozart - Symphony No. 25 in G minor.mp3 initial_offset:  60 iterations:  3 duration:  469.3
# label classical duration 890.8
# label classical duration 321.1
# song:  /content/drive/My Drive/Songs/all_songs/classical/Carl Orff - O Fortuna ~ Carmina Burana.mp3 initial_offset:  60 iterations:  3 duration:  321.1
# label classical duration 990.1
# label classical duration 908.0
# label classical duration 526.2
# song:  /content/drive/My Drive/Songs/all_songs/classical/Beethoven - Symphony No.7 in A major op.92 - II, Allegretto.mp3 initial_offset:  60 iterations:  3 duration:  526.2
# label classical duration 780.0
# label classical duration 239.6
# song:  /content/drive/My Drive/Songs/all_songs/classical/Jean Baptiste Lully - Ballet de la Nuit. - Antoine Watteau.mp3 initial_offset:  60 iterations:  3 duration:  239.6
# label classical duration 533.9
# song:  /content/drive/My Drive/Songs/all_songs/classical/Maxim Vengerov - Jean Sibelius - Violin Concerto in D minor, Op. 47, 2nd Movement Adagio Di Molto.mp3 initial_offset:  60 iterations:  3 duration:  533.9
# label classical duration 429.2
# song:  /content/drive/My Drive/Songs/all_songs/classical/A LATE QUARTET (Original Soundtrack Excerpt) - Beethoven String Quartet Op. 131 No. 14.mp3 initial_offset:  60 iterations:  3 duration:  429.2
# label classical duration 110.1
# song:  /content/drive/My Drive/Songs/all_songs/classical/Schubert - I see You!.mp3 initial_offset:  60 iterations:  3 duration:  110.1
# label classical duration 363.8
# song:  /content/drive/My Drive/Songs/all_songs/classical/Ludwig van Beethoven - Moonlight Sonata (Adagio Sostenuto).mp3 initial_offset:  60 iterations:  3 duration:  363.8
# label classical duration 730.1
# label classical duration 302.2
# song:  /content/drive/My Drive/Songs/all_songs/classical/CLAUDE DEBUSSY:  CLAIR DE LUNE.mp3 initial_offset:  60 iterations:  3 duration:  302.2
# label classical duration 429.7
# song:  /content/drive/My Drive/Songs/all_songs/classical/Camille Saint-Saëns - Danse Macabre.mp3 initial_offset:  60 iterations:  3 duration:  429.7
# label classical duration 397.5
# song:  /content/drive/My Drive/Songs/all_songs/classical/Frédéric Chopin: Nocturne in B-Flat Minor, Op. 9, No. 1.mp3 initial_offset:  60 iterations:  3 duration:  397.5
# label classical duration 576.5
# song:  /content/drive/My Drive/Songs/all_songs/classical/Jean Sibelius - Finlandia.mp3 initial_offset:  60 iterations:  3 duration:  576.5
# label classical duration 557.4
# song:  /content/drive/My Drive/Songs/all_songs/classical/Requiem 1 Giuseppe Verdi - Dies irae, Libera me.mp3 initial_offset:  60 iterations:  3 duration:  557.4
# label classical duration 331.2
# song:  /content/drive/My Drive/Songs/all_songs/classical/Chopin, Fantaisie Impromptu.mp3 initial_offset:  60 iterations:  3 duration:  331.2
# label classical duration 424.8
# song:  /content/drive/My Drive/Songs/all_songs/classical/Beethoven's 5th Symphony.mp3 initial_offset:  60 iterations:  3 duration:  424.8
# label classical duration 4790.1
# label classical duration 2519.6
# label classical duration 899.9
# label classical duration 3162.9
# label classical duration 447.2
# song:  /content/drive/My Drive/Songs/all_songs/classical/Moonlight Sonata.mp3 initial_offset:  60 iterations:  3 duration:  447.2
# label classical duration 290.4
# song:  /content/drive/My Drive/Songs/all_songs/classical/Claire De Lune.mp3 initial_offset:  60 iterations:  3 duration:  290.4
# label classical duration 533.6
# song:  /content/drive/My Drive/Songs/all_songs/classical/Mozart - Requiem.mp3 initial_offset:  60 iterations:  3 duration:  533.6
# label hip_hop_rap duration 335.3
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Future - Life Is Good (Official Music Video) ft. Drake.mp3 initial_offset:  60 iterations:  3 duration:  335.3
# label hip_hop_rap duration 220.2
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Megan Thee Stallion - Big Ole Freak [Official Video].mp3 initial_offset:  60 iterations:  3 duration:  220.2
# label hip_hop_rap duration 231.3
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/City Girls - Twerk ft. Cardi B (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  231.3
# label hip_hop_rap duration 212.8
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Roddy Ricch - The Box [Official Music Video].mp3 initial_offset:  60 iterations:  3 duration:  212.8
# label hip_hop_rap duration 158.0
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Saucy Santana - Up & Down Ft. Mulatto [Official Music Video].mp3 initial_offset:  60 iterations:  3 duration:  158.0
# label hip_hop_rap duration 163.9
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Rod Wave - Heart On Ice (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  163.9
# label hip_hop_rap duration 175.2
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/NLE Choppa - Walk Em Down feat. Roddy Ricch (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  175.2
# label hip_hop_rap duration 180.2
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Lil Mosey - Blueberry Faygo (Dir. by @_ColeBennett_).mp3 initial_offset:  60 iterations:  3 duration:  180.2
# label hip_hop_rap duration 229.2
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Mulatto - B*tch From Da Souf (Remix) (Official Video) ft. Saweetie & Trina.mp3 initial_offset:  60 iterations:  3 duration:  229.2
# label hip_hop_rap duration 180.7
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/DDG - OD (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  180.7
# label hip_hop_rap duration 167.8
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Playboi Carti - @ MEH [Official Video].mp3 initial_offset:  60 iterations:  3 duration:  167.8
# label hip_hop_rap duration 200.1
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Rod Wave - The Last Sad Song (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  200.1
# label hip_hop_rap duration 104.3
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Mulatto - No Hook (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  104.3
# label hip_hop_rap duration 143.6
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/King Von - Grandson for President (Remix) (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  143.6
# label hip_hop_rap duration 150.0
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Drake - Pain 1993 (Audio) ft. Playboi Carti.mp3 initial_offset:  60 iterations:  3 duration:  150.0
# label hip_hop_rap duration 117.5
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Fredo Bang - Top (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  117.5
# label hip_hop_rap duration 197.9
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Lil Baby - Emotionally Scarred (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  197.9
# label hip_hop_rap duration 160.1
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Rod Wave - Girl Of My Dreams (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  160.1
# label hip_hop_rap duration 266.1
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Eminem - Godzilla ft. Juice WRLD (Dir. by @_ColeBennett_).mp3 initial_offset:  60 iterations:  3 duration:  266.1
# label hip_hop_rap duration 179.6
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Young Dolph - Sunshine (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  179.6
# label hip_hop_rap duration 169.0
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Future - Trillionaire (Audio) ft. Youngboy Never Broke Again.mp3 initial_offset:  60 iterations:  3 duration:  169.0
# label hip_hop_rap duration 174.5
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Moneybagg Yo - Me Vs Me (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  174.5
# label hip_hop_rap duration 190.8
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Gunna - WUNNA [Official Video].mp3 initial_offset:  60 iterations:  3 duration:  190.8
# label hip_hop_rap duration 145.7
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Rod Wave - And I Still (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  145.7
# label hip_hop_rap duration 148.4
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Curtis Waters - Stunnin' ft. Harm Franklin (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  148.4
# label hip_hop_rap duration 169.0
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Lil Durk - Street Prayer (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  169.0
# label hip_hop_rap duration 175.7
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/King Von - Broke Opps (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  175.7
# label hip_hop_rap duration 158.1
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Kevin Gates - Grandmotha Grave [Official Music Video].mp3 initial_offset:  60 iterations:  3 duration:  158.1
# label hip_hop_rap duration 180.2
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Gucci Mane - Both Sides feat. Lil Baby.mp3 initial_offset:  60 iterations:  3 duration:  180.2
# label hip_hop_rap duration 175.3
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Juice WRLD - Tell Me U Luv Me ft. Trippie Redd (Dir. by @_ColeBennett_).mp3 initial_offset:  60 iterations:  3 duration:  175.3
# label hip_hop_rap duration 148.7
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/6IX9INE- GOOBA (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  148.7
# label hip_hop_rap duration 149.2
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/StaySolidRocky- Party Girl (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  149.2
# label hip_hop_rap duration 244.9
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Hopsin - Kumbaya.mp3 initial_offset:  60 iterations:  3 duration:  244.9
# label hip_hop_rap duration 256.6
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Lil Baby - The Bigger Picture (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  256.6
# label hip_hop_rap duration 182.8
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Toosii - Mercedez [Official Video].mp3 initial_offset:  60 iterations:  3 duration:  182.8
# label hip_hop_rap duration 167.3
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/THE SCOTTS, Travis Scott, Kid Cudi - THE SCOTTS (FORTNITE ASTRONOMICAL EVENT).mp3 initial_offset:  60 iterations:  3 duration:  167.3
# label hip_hop_rap duration 222.2
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/The Kid LAROI, Juice WRLD - GO (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  222.2
# label hip_hop_rap duration 186.3
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Polo G - 21 (Dir. by @_ColeBennett_).mp3 initial_offset:  60 iterations:  3 duration:  186.3
# label hip_hop_rap duration 150.2
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Saweetie - Tap In [Official Music Video].mp3 initial_offset:  60 iterations:  3 duration:  150.2
# label hip_hop_rap duration 173.5
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Lil Loaded ft. NLE Choppa "6locc 6a6y Remix" (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  173.5
# label hip_hop_rap duration 211.0
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/YFN Lucci - Wet (She Got That...) (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  211.0
# label hip_hop_rap duration 181.8
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Lil Durk - 3 Headed Goat ft. Lil Baby & Polo G (Dir. by @_ColeBennett_).mp3 initial_offset:  60 iterations:  3 duration:  181.8
# label hip_hop_rap duration 242.6
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Gucci Mane - Still Remember feat. Pooh Shiesty.mp3 initial_offset:  60 iterations:  3 duration:  242.6
# label hip_hop_rap duration 187.5
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/A Boogie Wit Da Hoodie - Bleed [Official Music Video].mp3 initial_offset:  60 iterations:  3 duration:  187.5
# label hip_hop_rap duration 180.5
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Tyga - Ibiza (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  180.5
# label hip_hop_rap duration 156.5
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Lil Mosey - Back At It ft. Lil Baby [Audio].mp3 initial_offset:  60 iterations:  3 duration:  156.5
# label hip_hop_rap duration 149.2
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Blueface - Finesse the Beat.mp3 initial_offset:  60 iterations:  3 duration:  149.2
# label hip_hop_rap duration 271.1
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Young Dolph - Blue Diamonds (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  271.1
# label hip_hop_rap duration 197.2
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/NLE Choppa - Shotta Flow 5 (Dir. by @_ColeBennett_).mp3 initial_offset:  60 iterations:  3 duration:  197.2
# label hip_hop_rap duration 178.9
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Moneybagg Yo – Said Sum (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  178.9
# label hip_hop_rap duration 174.1
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Lil Baby x 42 Dugg - We Paid (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  174.1
# label hip_hop_rap duration 165.0
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Megan Thee Stallion - Girls in the Hood [Lyric Video].mp3 initial_offset:  60 iterations:  3 duration:  165.0
# label hip_hop_rap duration 186.8
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Moneybagg Yo - Cold Shoulder.mp3 initial_offset:  60 iterations:  3 duration:  186.8
# label hip_hop_rap duration 183.9
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Megan Thee Stallion - Captain Hook [Official Video].mp3 initial_offset:  60 iterations:  3 duration:  183.9
# label hip_hop_rap duration 191.4
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Pop Smoke - For The Night (Audio) ft. Lil Baby, DaBaby.mp3 initial_offset:  60 iterations:  3 duration:  191.4
# label hip_hop_rap duration 301.4
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Pop Smoke ft. Lil Baby, DaBaby "For The Night" (Music Video).mp3 initial_offset:  60 iterations:  3 duration:  301.4
# label hip_hop_rap duration 170.0
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Polo G - 33 (Official Video) 🎥By. Ryan Lynch.mp3 initial_offset:  60 iterations:  3 duration:  170.0
# label hip_hop_rap duration 206.9
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/The Kid LAROI - Tell Me Why (Dir. by @_ColeBennett_).mp3 initial_offset:  60 iterations:  3 duration:  206.9
# label hip_hop_rap duration 227.6
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Jack Harlow - WHATS POPPIN feat. Dababy, Tory Lanez, & Lil Wayne [Official Music Video].mp3 initial_offset:  60 iterations:  3 duration:  227.6
# label hip_hop_rap duration 235.5
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/J. Cole - Snow On Tha Bluff (Official Audio).mp3 initial_offset:  60 iterations:  3 duration:  235.5
# label hip_hop_rap duration 311.5
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Drake - Toosie Slide (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  311.5
# label hip_hop_rap duration 192.5
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Toosii - Inside Out [Official Music Video].mp3 initial_offset:  60 iterations:  3 duration:  192.5
# label hip_hop_rap duration 178.4
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Lil Durk - When We Shoot (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  178.4
# label hip_hop_rap duration 169.4
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Youngboy Never Broke Again - Sticks with me (official video).mp3 initial_offset:  60 iterations:  3 duration:  169.4
# label hip_hop_rap duration 255.4
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/YNW Melly ft. Juice WRLD - Suicidal (Remix) [Official Video].mp3 initial_offset:  60 iterations:  3 duration:  255.4
# label hip_hop_rap duration 203.8
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Pop Smoke - The Woo ft. 50 Cent, Roddy Ricch.mp3 initial_offset:  60 iterations:  3 duration:  203.8
# label hip_hop_rap duration 202.0
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Juice WRLD - Wishing Well (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  202.0
# label hip_hop_rap duration 157.0
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Youngboy Never Broke Again- All in (official music video).mp3 initial_offset:  60 iterations:  3 duration:  157.0
# label hip_hop_rap duration 128.0
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/The Kid LAROI - I WISH (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  128.0
# label hip_hop_rap duration 353.8
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Queen Naija - Pack Lite (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  353.8
# label hip_hop_rap duration 171.7
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/DaBaby x Stunna 4 Vegas - No Dribble.mp3 initial_offset:  60 iterations:  3 duration:  171.7
# label hip_hop_rap duration 231.7
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Rod Wave - Rags 2 Riches Ft. Lil Baby & ATR SonSon (Official Audio).mp3 initial_offset:  60 iterations:  3 duration:  231.7
# label hip_hop_rap duration 228.9
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/NLE Choppa - Make Em Say feat. Mulatto (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  228.9
# label hip_hop_rap duration 139.5
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/DaBaby - PEEPHOLE (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  139.5
# label hip_hop_rap duration 231.2
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Mulatto - Muwop (Official Video) ft. Gucci Mane.mp3 initial_offset:  60 iterations:  3 duration:  231.2
# label hip_hop_rap duration 150.3
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/24kGoldn - Mood (Official Video) ft. Iann Dior.mp3 initial_offset:  60 iterations:  3 duration:  150.3
# label hip_hop_rap duration 184.7
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/NLE Choppa - Murda Talk (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  184.7
# label hip_hop_rap duration 187.5
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/WAP (feat. Megan Thee Stallion).mp3 initial_offset:  60 iterations:  3 duration:  187.5
# label hip_hop_rap duration 151.2
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/YoungBoy Never Broke Again - Kacey talk (official music video).mp3 initial_offset:  60 iterations:  3 duration:  151.2
# label hip_hop_rap duration 174.1
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Mo3 & Kevin Gates - Broken Love (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  174.1
# label hip_hop_rap duration 216.2
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Internet Money - Lemonade ft. Don Toliver, Gunna & Nav (Dir. by @_ColeBennett_).mp3 initial_offset:  60 iterations:  3 duration:  216.2
# label hip_hop_rap duration 301.3
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Drake - Laugh Now Cry Later (Official Music Video) ft. Lil Durk.mp3 initial_offset:  60 iterations:  3 duration:  301.3
# label hip_hop_rap duration 173.9
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Rod Wave - Letter From Houston (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  173.9
# label hip_hop_rap duration 194.8
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Polo G - Be Something (Official Audio) ft. Lil Baby.mp3 initial_offset:  60 iterations:  3 duration:  194.8
# label hip_hop_rap duration 269.3
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/nba youngboy - death enclaimed.mp3 initial_offset:  60 iterations:  3 duration:  269.3
# label hip_hop_rap duration 187.5
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Cardi B - WAP feat. Megan Thee Stallion [Official Lyric Video].mp3 initial_offset:  60 iterations:  3 duration:  187.5
# label hip_hop_rap duration 240.3
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/NLE Choppa - Narrow Road ft. Lil Baby (Official Audio).mp3 initial_offset:  60 iterations:  3 duration:  240.3
# label hip_hop_rap duration 161.1
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Lil Durk - Watch Yo Homie (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  161.1
# label hip_hop_rap duration 200.7
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Juice WRLD - Fighting Demons (Official Audio).mp3 initial_offset:  60 iterations:  3 duration:  200.7
# label hip_hop_rap duration 181.8
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/DaBaby – ROCKSTAR FT RODDY RICCH [Audio].mp3 initial_offset:  60 iterations:  3 duration:  181.8
# label hip_hop_rap duration 201.7
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/DJ Khaled ft. Drake - POPSTAR (Official Audio).mp3 initial_offset:  60 iterations:  3 duration:  201.7
# label hip_hop_rap duration 181.2
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Tom MacDonald - "People So Stupid".mp3 initial_offset:  60 iterations:  3 duration:  181.2
# label hip_hop_rap duration 197.9
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Polo G - Martin & Gina (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  197.9
# label hip_hop_rap duration 160.7
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Dustystaytrue - Never Change (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  160.7
# label hip_hop_rap duration 221.9
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Rod Wave - Through The Wire (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  221.9
# label hip_hop_rap duration 171.3
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Yo Gotti - Stay Ur Distance (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  171.3
# label hip_hop_rap duration 312.6
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/SZA - Hit Different (Official Video) ft. Ty Dolla $ign.mp3 initial_offset:  60 iterations:  3 duration:  312.6
# label hip_hop_rap duration 143.1
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/YoungBoy Never Broke Again - Callin (feat. Snoop Dogg) [Official Music Video].mp3 initial_offset:  60 iterations:  3 duration:  143.1
# label hip_hop_rap duration 195.4
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Cordae - Gifted ft. Roddy Ricch (Dir. by @_ColeBennett_).mp3 initial_offset:  60 iterations:  3 duration:  195.4
# label hip_hop_rap duration 200.7
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Big Sean - Wolves (Audio) ft. Post Malone.mp3 initial_offset:  60 iterations:  3 duration:  200.7
# label hip_hop_rap duration 485.6
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/DJ Khaled ft. Drake - POPSTAR (Official Music Video - Starring Justin Bieber).mp3 initial_offset:  60 iterations:  3 duration:  485.6
# label hip_hop_rap duration 179.1
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Sprado - MAGIC feat. NLE Choppa (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  179.1
# label hip_hop_rap duration 166.0
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/6IX9INE - TUTU (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  166.0
# label hip_hop_rap duration 207.4
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Big Sean - Lithuania ft. Travis Scott.mp3 initial_offset:  60 iterations:  3 duration:  207.4
# label hip_hop_rap duration 139.2
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Blueface - Baby (Dir. by @_ColeBennett_).mp3 initial_offset:  60 iterations:  3 duration:  139.2
# label hip_hop_rap duration 196.0
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Migos - Need It (Official Video) ft. YoungBoy Never Broke Again.mp3 initial_offset:  60 iterations:  3 duration:  196.0
# label hip_hop_rap duration 183.6
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/Badda TD - Bankroll (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  183.6
# label hip_hop_rap duration 214.1
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/TiaCorine - Mine ( Official Music Video ).mp3 initial_offset:  60 iterations:  3 duration:  214.1
# label hip_hop_rap duration 166.6
# song:  /content/drive/My Drive/Songs/all_songs/hip_hop_rap/POP SMOKE - GOT IT ON ME (OFFICIAL VIDEO).mp3 initial_offset:  60 iterations:  3 duration:  166.6
# label metal duration 294.6
# song:  /content/drive/My Drive/Songs/all_songs/metal/Iron Maiden - The Number Of The Beast (Low Definition).mp3 initial_offset:  60 iterations:  3 duration:  294.6
# label metal duration 310.6
# song:  /content/drive/My Drive/Songs/all_songs/metal/Mercyful Fate - A Dangerous Meeting (HQ audio).mp3 initial_offset:  60 iterations:  3 duration:  310.6
# label metal duration 216.0
# song:  /content/drive/My Drive/Songs/all_songs/metal/Slayer- Raining Blood (lyrics).mp3 initial_offset:  60 iterations:  3 duration:  216.0
# label metal duration 228.5
# song:  /content/drive/My Drive/Songs/all_songs/metal/Megadeth Burnt Ice (Studio Version).mp3 initial_offset:  60 iterations:  3 duration:  228.5
# label metal duration 311.3
# song:  /content/drive/My Drive/Songs/all_songs/metal/Lamb of God - Walk With Me In Hell.mp3 initial_offset:  60 iterations:  3 duration:  311.3
# label metal duration 324.9
# song:  /content/drive/My Drive/Songs/all_songs/metal/Annihilator - Alison Hell [OFFICIAL VIDEO].mp3 initial_offset:  60 iterations:  3 duration:  324.9
# label metal duration 396.2
# song:  /content/drive/My Drive/Songs/all_songs/metal/Creeping Death-Metallica.mp3 initial_offset:  60 iterations:  3 duration:  396.2
# label metal duration 252.4
# song:  /content/drive/My Drive/Songs/all_songs/metal/Iron Maiden - The Trooper.mp3 initial_offset:  60 iterations:  3 duration:  252.4
# label metal duration 315.2
# song:  /content/drive/My Drive/Songs/all_songs/metal/Ozzy Osbourne Mr Crowley Legendado em Inglês e Português.mp3 initial_offset:  60 iterations:  3 duration:  315.2
# label metal duration 234.6
# song:  /content/drive/My Drive/Songs/all_songs/metal/Lamb of God - Laid to Rest (Official Video - Clean Version).mp3 initial_offset:  60 iterations:  3 duration:  234.6
# label metal duration 302.0
# song:  /content/drive/My Drive/Songs/all_songs/metal/Slipknot - Psychosocial [OFFICIAL VIDEO].mp3 initial_offset:  60 iterations:  3 duration:  302.0
# label metal duration 157.3
# song:  /content/drive/My Drive/Songs/all_songs/metal/Judas Priest - Breaking The Law (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  157.3
# label metal duration 340.9
# song:  /content/drive/My Drive/Songs/all_songs/metal/Avenged Sevenfold - Beast and the Harlot (With lyrics).mp3 initial_offset:  60 iterations:  3 duration:  340.9
# label metal duration 395.0
# song:  /content/drive/My Drive/Songs/all_songs/metal/Slayer - Seasons In The Abyss.mp3 initial_offset:  60 iterations:  3 duration:  395.0
# label metal duration 602.9
# label metal duration 508.3
# song:  /content/drive/My Drive/Songs/all_songs/metal/Rainbow - Stargazer (with lyrics).mp3 initial_offset:  60 iterations:  3 duration:  508.3
# label metal duration 250.7
# song:  /content/drive/My Drive/Songs/all_songs/metal/Disturbed - Stricken [Official Music Video].mp3 initial_offset:  60 iterations:  3 duration:  250.7
# label metal duration 273.5
# song:  /content/drive/My Drive/Songs/all_songs/metal/BLACK SABBATH - _Paranoid_ Birmingham 2012 (Live Video).mp3 initial_offset:  60 iterations:  3 duration:  273.5
# label metal duration 421.7
# song:  /content/drive/My Drive/Songs/all_songs/metal/Trivium - In Waves [OFFICIAL VIDEO].mp3 initial_offset:  60 iterations:  3 duration:  421.7
# label metal duration 325.7
# song:  /content/drive/My Drive/Songs/all_songs/metal/Metallica-Battery.mp3 initial_offset:  60 iterations:  3 duration:  325.7
# label metal duration 251.0
# song:  /content/drive/My Drive/Songs/all_songs/metal/Megadeth - Peace Sells Music Video FULL!!!.mp3 initial_offset:  60 iterations:  3 duration:  251.0
# label metal duration 242.0
# song:  /content/drive/My Drive/Songs/all_songs/metal/Slipknot - Before I Forget [OFFICIAL VIDEO].mp3 initial_offset:  60 iterations:  3 duration:  242.0
# label metal duration 297.4
# song:  /content/drive/My Drive/Songs/all_songs/metal/Slayer ~ Angel of Death (Lyrics).mp3 initial_offset:  60 iterations:  3 duration:  297.4
# label metal duration 421.3
# song:  /content/drive/My Drive/Songs/all_songs/metal/Metallica - Fade To Black (Music Video).mp3 initial_offset:  60 iterations:  3 duration:  421.3
# label metal duration 353.8
# song:  /content/drive/My Drive/Songs/all_songs/metal/Dio - Holy Diver.mp3 initial_offset:  60 iterations:  3 duration:  353.8
# label metal duration 247.2
# song:  /content/drive/My Drive/Songs/all_songs/metal/Lamb of God - Redneck (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  247.2
# label metal duration 292.4
# song:  /content/drive/My Drive/Songs/all_songs/metal/Slayer - War Ensemble.mp3 initial_offset:  60 iterations:  3 duration:  292.4
# label metal duration 407.6
# song:  /content/drive/My Drive/Songs/all_songs/metal/Metallica Ride The Lightning.mp3 initial_offset:  60 iterations:  3 duration:  407.6
# label metal duration 223.4
# song:  /content/drive/My Drive/Songs/all_songs/metal/Death_ Lack Of Comprehension.mp3 initial_offset:  60 iterations:  3 duration:  223.4
# label metal duration 320.2
# song:  /content/drive/My Drive/Songs/all_songs/metal/Metallica - For Whom the Bell Tolls {Offical Music Video}.mp3 initial_offset:  60 iterations:  3 duration:  320.2
# label metal duration 433.2
# song:  /content/drive/My Drive/Songs/all_songs/metal/The Four Horsemen - Metallica.mp3 initial_offset:  60 iterations:  3 duration:  433.2
# label metal duration 453.0
# song:  /content/drive/My Drive/Songs/all_songs/metal/Iron Maiden- Phantom Of The Opera.mp3 initial_offset:  60 iterations:  3 duration:  453.0
# label metal duration 306.0
# song:  /content/drive/My Drive/Songs/all_songs/metal/Iron Maiden - Wasted Years (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  306.0
# label metal duration 300.1
# song:  /content/drive/My Drive/Songs/all_songs/metal/DragonForce - Through the Fire and Flames (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  300.1
# label metal duration 285.6
# song:  /content/drive/My Drive/Songs/all_songs/metal/Disturbed - The Night (With Lyrics).mp3 initial_offset:  60 iterations:  3 duration:  285.6
# label metal duration 304.1
# song:  /content/drive/My Drive/Songs/all_songs/metal/Pantera - Domination (HQ Studio version W lyrics).mp3 initial_offset:  60 iterations:  3 duration:  304.1
# label metal duration 482.5
# song:  /content/drive/My Drive/Songs/all_songs/metal/Metallica - Blackened.mp3 initial_offset:  60 iterations:  3 duration:  482.5
# label metal duration 327.3
# song:  /content/drive/My Drive/Songs/all_songs/metal/Metallica - Enter Sandman lyrics.mp3 initial_offset:  60 iterations:  3 duration:  327.3
# label metal duration 832.7
# label metal duration 274.5
# song:  /content/drive/My Drive/Songs/all_songs/metal/Insomnium - _Mortal Share_ CandlelightPeaceville Records.mp3 initial_offset:  60 iterations:  3 duration:  274.5
# label metal duration 223.3
# song:  /content/drive/My Drive/Songs/all_songs/metal/System Of A Down - Toxicity (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  223.3
# label metal duration 472.5
# song:  /content/drive/My Drive/Songs/all_songs/metal/Black sabbath-War Pigs (lyrics).mp3 initial_offset:  60 iterations:  3 duration:  472.5
# label metal duration 216.3
# song:  /content/drive/My Drive/Songs/all_songs/metal/Disturbed - Down With The Sickness [Official Music Video].mp3 initial_offset:  60 iterations:  3 duration:  216.3
# label metal duration 427.0
# song:  /content/drive/My Drive/Songs/all_songs/metal/Cemetery Gates - Pantera (HQ Audio).mp3 initial_offset:  60 iterations:  3 duration:  427.0
# label metal duration 375.1
# song:  /content/drive/My Drive/Songs/all_songs/metal/Avenged Sevenfold - Nightmare (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  375.1
# label metal duration 276.7
# song:  /content/drive/My Drive/Songs/all_songs/metal/Bullet For My Valentine - Tears Don't Fall (Album Edit - with Scream  with Lighter).mp3 initial_offset:  60 iterations:  3 duration:  276.7
# label metal duration 315.9
# song:  /content/drive/My Drive/Songs/all_songs/metal/Pantera - Walk (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  315.9
# label metal duration 206.6
# song:  /content/drive/My Drive/Songs/all_songs/metal/System Of A Down - Chop Suey! (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  206.6
# label metal duration 357.6
# song:  /content/drive/My Drive/Songs/all_songs/metal/OZZY OSBOURNE - _No More Tears_ (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  357.6
# label metal duration 330.9
# song:  /content/drive/My Drive/Songs/all_songs/metal/Metallica_ Enter Sandman (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  330.9
# label metal duration 431.0
# song:  /content/drive/My Drive/Songs/all_songs/metal/Iron Maiden - Hallowed Be Thy Name (Studio Version).mp3 initial_offset:  60 iterations:  3 duration:  431.0
# label metal duration 384.0
# song:  /content/drive/My Drive/Songs/all_songs/metal/Metallica - Wherever I May Roam.mp3 initial_offset:  60 iterations:  3 duration:  384.0
# label metal duration 244.5
# song:  /content/drive/My Drive/Songs/all_songs/metal/Five Finger Death Punch - Under And Over It.mp3 initial_offset:  60 iterations:  3 duration:  244.5
# label metal duration 426.8
# song:  /content/drive/My Drive/Songs/all_songs/metal/Metallica - One (Full Lyrics).mp3 initial_offset:  60 iterations:  3 duration:  426.8
# label metal duration 368.0
# song:  /content/drive/My Drive/Songs/all_songs/metal/Judas Priest - Painkiller.mp3 initial_offset:  60 iterations:  3 duration:  368.0
# label metal duration 385.7
# song:  /content/drive/My Drive/Songs/all_songs/metal/Metallica_ Nothing Else Matters (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  385.7
# label metal duration 447.5
# song:  /content/drive/My Drive/Songs/all_songs/metal/One.mp3 initial_offset:  60 iterations:  3 duration:  447.5
# label metal duration 316.4
# song:  /content/drive/My Drive/Songs/all_songs/metal/Rage Against The Machine - Killing In the Name (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  316.4
# label metal duration 414.2
# song:  /content/drive/My Drive/Songs/all_songs/metal/Iron Maiden - Run To The Hills.mp3 initial_offset:  60 iterations:  3 duration:  414.2
# label metal duration 338.0
# song:  /content/drive/My Drive/Songs/all_songs/metal/Ozzy Osbourne - Crazy Train (Speak Of The Devil).mp3 initial_offset:  60 iterations:  3 duration:  338.0
# label metal duration 237.6
# song:  /content/drive/My Drive/Songs/all_songs/metal/Pantera - Mouth For War (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  237.6
# label metal duration 252.8
# song:  /content/drive/My Drive/Songs/all_songs/metal/Evanescence - Bring Me To Life (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  252.8
# label metal duration 431.1
# song:  /content/drive/My Drive/Songs/all_songs/metal/Hallowed Be Thy Name (2015 Remaster).mp3 initial_offset:  60 iterations:  3 duration:  431.1
# label metal duration 397.2
# song:  /content/drive/My Drive/Songs/all_songs/metal/Megadeth - Holy Wars...The Punishment Due.mp3 initial_offset:  60 iterations:  3 duration:  397.2
# label metal duration 465.2
# song:  /content/drive/My Drive/Songs/all_songs/metal/Judas Priest - Victim Of Changes.mp3 initial_offset:  60 iterations:  3 duration:  465.2
# label metal duration 443.7
# song:  /content/drive/My Drive/Songs/all_songs/metal/Metallica - One.mp3 initial_offset:  60 iterations:  3 duration:  443.7
# label metal duration 212.0
# song:  /content/drive/My Drive/Songs/all_songs/metal/Ten Thousand Fists.mp3 initial_offset:  60 iterations:  3 duration:  212.0
# label metal duration 419.9
# song:  /content/drive/My Drive/Songs/all_songs/metal/Floods (2016 Remaster).mp3 initial_offset:  60 iterations:  3 duration:  419.9
# label metal duration 186.1
# song:  /content/drive/My Drive/Songs/all_songs/metal/Numb (Official Video) - Linkin Park.mp3 initial_offset:  60 iterations:  3 duration:  186.1
# label metal duration 248.4
# song:  /content/drive/My Drive/Songs/all_songs/metal/Whiplash.mp3 initial_offset:  60 iterations:  3 duration:  248.4
# label metal duration 414.6
# song:  /content/drive/My Drive/Songs/all_songs/metal/Seek & Destroy.mp3 initial_offset:  60 iterations:  3 duration:  414.6
# label metal duration 309.9
# song:  /content/drive/My Drive/Songs/all_songs/metal/For Whom The Bell Tolls.mp3 initial_offset:  60 iterations:  3 duration:  309.9
# label metal duration 297.4
# song:  /content/drive/My Drive/Songs/all_songs/metal/Marilyn Manson - Sweet Dreams (Are Made Of This) (Alt. Version).mp3 initial_offset:  60 iterations:  3 duration:  297.4
# label metal duration 351.8
# song:  /content/drive/My Drive/Songs/all_songs/metal/BLACK SABBATH - _Iron Man_ (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  351.8
# label metal duration 413.9
# song:  /content/drive/My Drive/Songs/all_songs/metal/Pink Floyd - Comfortably numb.mp3 initial_offset:  60 iterations:  3 duration:  413.9
# label metal duration 515.1
# song:  /content/drive/My Drive/Songs/all_songs/metal/Master Of Puppets.mp3 initial_offset:  60 iterations:  3 duration:  515.1
# label metal duration 239.0
# song:  /content/drive/My Drive/Songs/all_songs/metal/The White Stripes - 'Seven Nation Army'.mp3 initial_offset:  60 iterations:  3 duration:  239.0
# label metal duration 516.5
# song:  /content/drive/My Drive/Songs/all_songs/metal/Metallica-Master Of Puppets (Lyrics).mp3 initial_offset:  60 iterations:  3 duration:  516.5
# label metal duration 464.4
# song:  /content/drive/My Drive/Songs/all_songs/metal/Metallica_ One (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  464.4
# label metal duration 213.8
# song:  /content/drive/My Drive/Songs/all_songs/metal/Slipknot - Duality [OFFICIAL VIDEO].mp3 initial_offset:  60 iterations:  3 duration:  213.8
# label metal duration 507.2
# song:  /content/drive/My Drive/Songs/all_songs/metal/Orion (Remastered).mp3 initial_offset:  60 iterations:  3 duration:  507.2
# label metal duration 253.5
# song:  /content/drive/My Drive/Songs/all_songs/metal/ACDC - Back In Black (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  253.5
# label pop duration 270.8
# song:  /content/drive/My Drive/Songs/all_songs/pop/Maroon 5 - Girls Like You ft. Cardi B (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  270.8
# label pop duration 263.3
# song:  /content/drive/My Drive/Songs/all_songs/pop/Ed Sheeran - Perfect [Official Lyric Video].mp3 initial_offset:  60 iterations:  3 duration:  263.3
# label pop duration 216.9
# song:  /content/drive/My Drive/Songs/all_songs/pop/Alan Walker, Sabrina Carpenter & Farruko  - On My Way.mp3 initial_offset:  60 iterations:  3 duration:  216.9
# label pop duration 205.8
# song:  /content/drive/My Drive/Songs/all_songs/pop/Mabel - Bad Behaviour (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  205.8
# label pop duration 186.6
# song:  /content/drive/My Drive/Songs/all_songs/pop/Lewis Capaldi - Someone You Loved.mp3 initial_offset:  60 iterations:  3 duration:  186.6
# label pop duration 218.8
# song:  /content/drive/My Drive/Songs/all_songs/pop/Black Eyed Peas, J Balvin - RITMO (Bad Boys For Life).mp3 initial_offset:  60 iterations:  3 duration:  218.8
# label pop duration 263.2
# song:  /content/drive/My Drive/Songs/all_songs/pop/Ed Sheeran - Shape of You [Official Video].mp3 initial_offset:  60 iterations:  3 duration:  263.2
# label pop duration 163.6
# song:  /content/drive/My Drive/Songs/all_songs/pop/Arizona Zervas - ROXANNE (Prod. 94 Skrt).mp3 initial_offset:  60 iterations:  3 duration:  163.6
# label pop duration 159.1
# song:  /content/drive/My Drive/Songs/all_songs/pop/Bebe Rexha - You Can't Stop The Girl (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  159.1
# label pop duration 217.3
# song:  /content/drive/My Drive/Songs/all_songs/pop/The Chainsmokers - Call You Mine (Official Video) ft. Bebe Rexha.mp3 initial_offset:  60 iterations:  3 duration:  217.3
# label pop duration 221.0
# song:  /content/drive/My Drive/Songs/all_songs/pop/Ariana Grande, Social House - boyfriend (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  221.0
# label pop duration 284.6
# song:  /content/drive/My Drive/Songs/all_songs/pop/Zedd & Kehlani - Good Thing (Official Music Video).mp3 initial_offset:  60 iterations:  3 duration:  284.6
# label pop duration 176.1
# song:  /content/drive/My Drive/Songs/all_songs/pop/Lizzo - Tempo (feat. Missy Elliott) [Official Video].mp3 initial_offset:  60 iterations:  3 duration:  176.1
# label pop duration 183.7
# song:  /content/drive/My Drive/Songs/all_songs/pop/Jonas Brothers - Cool (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  183.7
# label pop duration 267.1
# song:  /content/drive/My Drive/Songs/all_songs/pop/Adam Levine & James Valentine “Memories” Live on the Howard Stern Show.mp3 initial_offset:  60 iterations:  3 duration:  267.1
# label pop duration 177.9
# song:  /content/drive/My Drive/Songs/all_songs/pop/SAINt JHN - ROSES (Imanbek Remix).mp3 initial_offset:  60 iterations:  3 duration:  177.9
# label pop duration 171.3
# song:  /content/drive/My Drive/Songs/all_songs/pop/Jax Jones, Bebe Rexha - Harder.mp3 initial_offset:  60 iterations:  3 duration:  171.3
# label pop duration 204.1
# song:  /content/drive/My Drive/Songs/all_songs/pop/Liam Payne & J Balvin - Familiar (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  204.1
# label pop duration 253.5
# song:  /content/drive/My Drive/Songs/all_songs/pop/Khalid - Right Back ft. A Boogie Wit Da Hoodie (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  253.5
# label pop duration 195.9
# song:  /content/drive/My Drive/Songs/all_songs/pop/Lauv - f_ck, i'm lonely (with Anne-Marie) [Official Visualizer].mp3 initial_offset:  60 iterations:  3 duration:  195.9
# label pop duration 188.3
# ...
# label narodni duration 214.7
# song:  /content/drive/My Drive/Songs/all_songs/narodni/narodni_21.mp3 initial_offset:  60 iterations:  3 duration:  214.7
# label narodni duration 260.7
# song:  /content/drive/My Drive/Songs/all_songs/narodni/narodni_8.mp3 initial_offset:  60 iterations:  3 duration:  260.7
# label jazz duration 381.2
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Chet Baker - But Not For Me.mp3 initial_offset:  60 iterations:  3 duration:  381.2
# label jazz duration 203.0
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_LESTER LEAPS IN    Count Basie Kansas City 7 FEATURING LESTER YOUNG.mp3 initial_offset:  60 iterations:  3 duration:  203.0
# label jazz duration 174.2
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Little Brown Jug Glenn Miller.mp3 initial_offset:  60 iterations:  3 duration:  174.2
# label jazz duration 185.8
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Milt Jackson - Bags Groove.mp3 initial_offset:  60 iterations:  3 duration:  185.8
# label jazz duration 186.1
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Charlie Parker - Scrapple from the Apple (1948).mp3 initial_offset:  60 iterations:  3 duration:  186.1
# label jazz duration 214.6
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Art Tatum plays Tea for Two.mp3 initial_offset:  60 iterations:  3 duration:  214.6
# label jazz duration 171.2
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Toots Thielemans - Bluesette (1964).mp3 initial_offset:  60 iterations:  3 duration:  171.2
# label jazz duration 149.8
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Barbados by Charlie Parker.mp3 initial_offset:  60 iterations:  3 duration:  149.8
# label jazz duration 227.5
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Lambert, Hendricks & Ross Hi-Fly The Hottest New Group In Jazz 1962.mp3 initial_offset:  60 iterations:  3 duration:  227.5
# label jazz duration 377.6
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Wes Montgomery - Four On Six - The Incredible Jazz Guitar Of Wes Montgomery.mp3 initial_offset:  60 iterations:  3 duration:  377.6
# label jazz duration 482.5
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Joe Henderson - Blue Bossa.mp3 initial_offset:  60 iterations:  3 duration:  482.5
# label jazz duration 400.5
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Chilli Peppers - Duke Pearson.mp3 initial_offset:  60 iterations:  3 duration:  400.5
# label jazz duration 202.9
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Thelonious Monk - Misterioso.mp3 initial_offset:  60 iterations:  3 duration:  202.9
# label jazz duration 403.7
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Wynton Kelly Trio (Wes Montgomery)_ Unit 7.mp3 initial_offset:  60 iterations:  3 duration:  403.7
# label jazz duration 256.1
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Killer Joe By Art Farmer & Benny Golson Jazztet.mp3 initial_offset:  60 iterations:  3 duration:  256.1
# label jazz duration 659.6
# label jazz duration 731.9
# label jazz duration 420.4
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Thelonious Monk and John Coltrane - Trinkle Tinkle.mp3 initial_offset:  60 iterations:  3 duration:  420.4
# label jazz duration 188.5
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_#Cast Your Fate to the Wind# Vince Guaraldi Trio.mp3 initial_offset:  60 iterations:  3 duration:  188.5
# label jazz duration 475.8
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Freddie Hubbard Little Sunflower Backlash 1967.mp3 initial_offset:  60 iterations:  3 duration:  475.8
# label jazz duration 269.6
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Thelonious Monk and John Coltrane - Epistrophy.mp3 initial_offset:  60 iterations:  3 duration:  269.6
# label jazz duration 174.3
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Gerry Mulligan Quartet - Bernie's Tune.mp3 initial_offset:  60 iterations:  3 duration:  174.3
# label jazz duration 304.3
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Dizzy Gillespie - Con Alma (Verve Records 1954).mp3 initial_offset:  60 iterations:  3 duration:  304.3
# label jazz duration 194.7
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Nat King Cole-(Get Your Kicks On) Route 66.mp3 initial_offset:  60 iterations:  3 duration:  194.7
# label jazz duration 350.9
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Stan Getz & Charlie Byrd - Desafinado (Verve Records 1962).mp3 initial_offset:  60 iterations:  3 duration:  350.9
# label jazz duration 462.9
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_John Coltrane - Acknowledgement.mp3 initial_offset:  60 iterations:  3 duration:  462.9
# label jazz duration 394.5
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Thelonious Monk-#Green Chimneys# from #Straight, No Chaser#.mp3 initial_offset:  60 iterations:  3 duration:  394.5
# label jazz duration 354.9
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Walk On The Wild Side.mp3 initial_offset:  60 iterations:  3 duration:  354.9
# label jazz duration 545.7
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Freddie Freeloader - Jon Hendricks & Friends.mp3 initial_offset:  60 iterations:  3 duration:  545.7
# label jazz duration 350.1
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Miles Davis - Milestones.mp3 initial_offset:  60 iterations:  3 duration:  350.1
# label jazz duration 445.7
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Randy Weston Quintet at the Five Spot - Hi-Fly.mp3 initial_offset:  60 iterations:  3 duration:  445.7
# label jazz duration 130.4
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Jimmy Smith  The Organ Grinder's Swing.mp3 initial_offset:  60 iterations:  3 duration:  130.4
# label jazz duration 369.1
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_OGD (aka Road Song).mp3 initial_offset:  60 iterations:  3 duration:  369.1
# label jazz duration 263.6
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Sarah Vaughan - Lullaby of Birdland.mp3 initial_offset:  60 iterations:  3 duration:  263.6
# label jazz duration 242.4
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Kenny Burrell - Midnight Blue.mp3 initial_offset:  60 iterations:  3 duration:  242.4
# label jazz duration 548.0
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Hank Mobley - Soul Station  1960 HQ.mp3 initial_offset:  60 iterations:  3 duration:  548.0
# label jazz duration 438.4
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Horace Silver - Song for My Father.mp3 initial_offset:  60 iterations:  3 duration:  438.4
# label jazz duration 342.5
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Hank Mobley - Remember.mp3 initial_offset:  60 iterations:  3 duration:  342.5
# label jazz duration 119.0
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_#Groove# Holmes - #Misty#.mp3 initial_offset:  60 iterations:  3 duration:  119.0
# label jazz duration 562.4
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_So What - Miles Davis (1959).mp3 initial_offset:  60 iterations:  3 duration:  562.4
# label jazz duration 612.7
# label jazz duration 826.8
# label jazz duration 500.4
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Wayne Shorter - Speak No Evil.mp3 initial_offset:  60 iterations:  3 duration:  500.4
# label jazz duration 184.6
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Bud Powell - Collard Greens and Black Eyed Peas.mp3 initial_offset:  60 iterations:  3 duration:  184.6
# label jazz duration 919.3
# label jazz duration 388.0
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Lee Morgan Quintet - Ceora.mp3 initial_offset:  60 iterations:  3 duration:  388.0
# label jazz duration 427.0
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Oscar Peterson   Night Train.mp3 initial_offset:  60 iterations:  3 duration:  292.0
# label jazz duration 332.7
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Duke Pearson Trio - Jeannine.mp3 initial_offset:  60 iterations:  3 duration:  332.7
# label jazz duration 177.6
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Thelonious Monk - Straight, No Chaser.mp3 initial_offset:  60 iterations:  3 duration:  177.6
# label jazz duration 186.3
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Benny Goodman   #Don't Be That Way#.mp3 initial_offset:  60 iterations:  3 duration:  186.3
# label jazz duration 526.9
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Art Blakey - Dat Dere.mp3 initial_offset:  60 iterations:  3 duration:  526.9
# label jazz duration 460.6
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Eddie Harris - Listen Here.mp3 initial_offset:  60 iterations:  3 duration:  460.6
# label jazz duration 696.4
# label jazz duration 546.5
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Miles Davis - So What (Official Video).mp3 initial_offset:  60 iterations:  3 duration:  546.5
# label jazz duration 591.7
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Miles Davis - On Green Dolphin street.mp3 initial_offset:  60 iterations:  3 duration:  591.7
# label jazz duration 589.2
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Miles Davis - Freddie Freeloader.mp3 initial_offset:  60 iterations:  3 duration:  589.2
# label jazz duration 496.5
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_If I Were A Bell - The Miles Davis Quintet.mp3 initial_offset:  60 iterations:  3 duration:  496.5
# label jazz duration 408.2
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_SONNY ROLLINS.St. Thomas.mp3 initial_offset:  60 iterations:  3 duration:  408.2
# label jazz duration 693.8
# label jazz duration 456.1
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Bill Evans - Night And Day (Everybody Digs Bill Evans).mp3 initial_offset:  60 iterations:  3 duration:  456.1
# label jazz duration 404.7
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Horace Silver - Doodlin' (1954).mp3 initial_offset:  60 iterations:  3 duration:  404.7
# label jazz duration 481.9
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Jimmy Smith & Stanley Turrentine - Back At The Chicken Shack.mp3 initial_offset:  60 iterations:  3 duration:  481.9
# label jazz duration 682.5
# label jazz duration 586.4
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Freddie Freeloader.mp3 initial_offset:  60 iterations:  3 duration:  586.4
# label jazz duration 659.5
# label jazz duration 512.1
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_John Coltrane - Equinox (Original).mp3 initial_offset:  60 iterations:  3 duration:  512.1
# label jazz duration 329.6
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Dave Brubeck - Take Five.mp3 initial_offset:  60 iterations:  3 duration:  329.6
# label jazz duration 178.4
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Duke Ellington - Take the 'a' Train.mp3 initial_offset:  60 iterations:  3 duration:  178.4
# label jazz duration 570.7
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Moanin'.mp3 initial_offset:  60 iterations:  3 duration:  570.7
# label jazz duration 547.5
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_Miles Davis Someday My Prince Will Come.mp3 initial_offset:  60 iterations:  3 duration:  547.5
# label jazz duration 824.1
# label jazz duration 896.1
# label jazz duration 211.1
# song:  /content/drive/My Drive/Songs/all_songs/jazz/jazz_This Here - Bobby Timmons.mp3 initial_offset:  60 iterations:  3 duration:  211.1

# %% [markdown]
# # Preprocessing

# %%
#Fast Fourier Transform
import scipy
def fft_plot(audio,sampling_rate,label):
  n = len(audio)
  T = 1/sampling_rate
  yf=scipy.fft(audio)
  xf=np.linspace(0,1.0/(2.0*T),int(n/2))
  fig,ax = plt.subplots()
  ax.plot(xf,2.0/n* np.abs(yf[:n//2]))
  plt.grid()
  plt.xlabel('Frequency ------->')
  plt.ylabel('Magnitude')
  plt.title(label)
  plt.show()


#Extract MFCC from spectogram
def extract_features(audio_path,offset):

    y, sr = librosa.load(audio_path, offset=offset, duration=4.5)

    
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zcr = librosa.feature.zero_crossing_rate(y)
    mfcc = librosa.feature.mfcc(y=y, sr=sr)

    vector = np.empty
    vector = np.append(vector, np.mean(chroma_stft))
    vector = np.append(vector, np.mean(spec_cent))
    vector = np.append(vector,np.mean(spec_bw))
    vector = np.append(vector,np.mean(rolloff))
    vector = np.append(vector,np.mean(zcr))
    for e in mfcc:
            vector = np.append(vector,np.mean(e))

    vector = np.delete(vector,0,0)


    return vector

# %%
dataset = pd.DataFrame(dataset)
dataset = shuffle(dataset, random_state=42)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1944 entries, 1610 to 1126
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  1944 non-null   object
#  1   label     1944 non-null   object
#  2   offset    1944 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 60.8+ KB

# %%
nuli = []
for i in range(649,len(dataset)):
  y,sr = librosa.load(dataset.filename.iloc[i], duration=3)
  if y.any() == 0:
    nuli.append(i)

# %%
dataset = dataset.drop(index=nuli)

# %%
len(dataset)
# Out:
# 1892

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (14, 5)
matplotlib.rcParams['font.size'] = 12
from matplotlib import pyplot as plt

num_classes = 9
class_counts = dataset.label.value_counts()
cmap = plt.cm.get_cmap(plt.cm.Set3, 10)
colors = [cmap(i) for i in range(num_classes)]
plt.barh(range(num_classes)[::-1], class_counts, tick_label=genres,
         color=colors)
plt.title('Class distribution of dataset')
plt.show()

# %%
train, test = train_test_split(dataset, test_size=0.25, random_state=42)

print("Train: %i" % len(train))
print("Test: %i" % len(test))
# Out:
# Train: 1419
# Test: 473

# %%
x_train = []
x_test = []

for idx in tqdm(range(len(train))):
    x_train.append(extract_features(train.filename.iloc[idx],train.offset.iloc[idx]))

for idx in tqdm(range(len(test))):
    x_test.append(extract_features(test.filename.iloc[idx],test.offset.iloc[idx]))
    
x_test = np.asarray(x_test)
x_train = np.asarray(x_train)

print("X train:", x_train.shape)
print("X test:", x_test.shape)
# Out:
# 100%|██████████| 1419/1419 [22:56<00:00,  1.03it/s]
# 100%|██████████| 473/473 [05:54<00:00,  1.33it/s]
# X train: (1419, 25)
# X test: (473, 25)

# %%
encoder = LabelEncoder()

y_train = encoder.fit_transform(train.label)
y_test = encoder.fit_transform(test.label)

# Compute class weights
class_weights = class_weight.compute_class_weight('balanced',np.unique(y_train),y_train)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(np.array(x_train, dtype = float))
x_test = scaler.fit_transform(np.array(x_test, dtype = float))

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1419, 25)
# (1419,)
# (473, 25)
# (473,)

# %%
import sklearn

def confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
   
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = numpy.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

def plot_cnf(model,dataset_x,dataset_y,GENRES):
    true_y=dataset_y
    true_x=dataset_x
    pred=model.predict(true_x)

    print("---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------\n")

    print("Real Test dataset labels: \n{}\n".format(true_y))
    print("Predicted Test dataset labels: \n{}".format(pred))

    cnf_matrix=sklearn.metrics.confusion_matrix(true_y,pred)
    plt.figure()
    a=confusion_matrix(cnf_matrix,classes=GENRES,title='Confusion matrix')

# %% [markdown]
# # K-Nearest Neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier

results_knn=[]
for i in range(1,11):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    results_knn.append(knn.score(x_test,y_test))
    
max_accuracy_knn=max(results_knn)
best_k=1+results_knn.index(max(results_knn))
print("Max Accuracy is {:.3f} on test dataset with {} neighbors.\n".format(max_accuracy_knn,best_k))

plt.plot(numpy.arange(1,11),results_knn)
plt.xlabel("n Neighbors")
plt.ylabel("Accuracy")


knn=KNeighborsClassifier(n_neighbors=best_k)
knn.fit(x_train,y_train)
print("Training Score: {:.3f}".format(knn.score(x_train,y_train)))
print("Test score: {:.3f}".format(knn.score(x_test,y_test)))  

plot_cnf(knn,x_test,y_test,genres)
# Out:
# Max Accuracy is 0.820 on test dataset with 1 neighbors.
#
# Training Score: 0.991
# Test score: 0.820
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# [7 4 6 2 8 3 1 4 5 1 3 1 7 1 3 8 3 0 2 5 6 6 3 1 5 2 3 5 5 2 0 4 1 0 8 3 7
#  1 3 1 7 6 1 5 3 5 5 5 3 1 6 6 8 2 3 6 5 7 7 0 6 1 5 1 3 1 1 1 6 7 3 8 3 4
#  5 2 3 1 2 5 1 5 6 6 4 1 3 5 5 2 2 1 1 1 1 4 3 3 5 6 6 6 5 6 1 6 6 8 1 2 1
#  5 1 3 8 5 0 4 1 5 2 5 1 8 8 3 7 0 6 0 1 2 3 5 0 5 3 6 7 2 5 1 6 2 6 1 7 5
#  3 6 1 0 5 1 3 6 6 3 1 3 6 4 6 7 5 5 6 5 4 4 8 3 3 3 2 1 6 2 8 1 1 7 2 4 2
#  4 0 6 2 3 4 3 1 4 5 7 1 2 3 6 4 8 1 2 3 1 1 3 0 2 5 3 8 1 3 1 2 2 1 1 2 8
#  4 6 5 7 6 5 0 5 4 6 3 4 4 6 3 2 0 7 3 2 7 2 2 5 3 2 0 0 1 6 4 4 3 2 1 3 6
#  7 6 0 6 6 7 0 6 5 5 2 3 2 0 0 5 2 6 1 5 2 6 6 5 6 8 6 5 2 7 6 3 1 1 5 6 6
#  2 4 6 7 1 1 3 6 5 6 7 7 4 7 1 2 5 4 5 8 6 3 3 5 4 1 2 2 0 5 0 2 2 3 1 3 2
#  1 2 2 6 6 5 1 3 0 2 1 3 1 3 0 5 5 7 5 5 1 0 6 1 3 3 3 1 1 5 1 7 0 1 6 3 5
#  6 4 3 8 2 7 6 6 3 1 6 6 6 2 1 6 2 1 2 3 4 3 1 8 2 2 6 3 1 8 1 3 2 2 6 1 1
#  2 5 1 1 5 5 2 2 1 4 7 0 0 3 3 0 4 7 6 1 5 5 3 5 0 7 5 5 6 2 1 3 2 6 4 5 5
#  3 6 7 1 6 5 6 2 6 0 6 0 6 1 8 6 5 1 7 5 3 3 4 6 8 8 1 5 4]
#
# Predicted Test dataset labels:
# [7 4 6 2 8 3 1 4 5 1 3 1 7 1 3 8 3 2 2 5 6 6 3 1 6 2 3 5 6 2 0 4 1 0 8 3 7
#  1 3 1 7 6 1 6 3 5 5 5 3 1 5 3 2 2 3 7 5 6 7 0 3 1 5 4 3 1 1 1 6 7 3 8 3 4
#  5 2 3 7 2 5 1 5 6 6 4 6 3 1 5 2 2 1 1 0 1 2 6 3 5 6 6 3 5 6 1 6 2 8 1 2 1
#  1 1 3 8 5 0 4 1 5 2 5 1 8 3 3 7 0 6 0 1 2 3 5 0 5 3 6 7 2 5 1 6 2 6 1 7 5
#  3 6 5 0 7 1 3 6 7 6 1 3 5 0 6 7 2 5 6 5 4 4 2 3 3 3 2 5 7 2 8 1 2 7 2 2 3
#  4 0 6 2 3 4 3 1 4 5 2 1 2 3 0 4 6 1 2 6 1 1 6 0 2 7 3 3 1 3 1 2 2 2 1 2 8
#  4 6 1 1 3 5 8 7 7 6 3 4 4 3 3 2 0 7 3 2 6 2 2 5 6 2 0 0 1 6 3 0 1 2 1 3 3
#  6 6 0 6 6 7 0 7 5 5 2 3 2 0 8 3 2 6 1 5 2 6 6 5 6 2 6 5 2 7 6 3 1 1 5 6 6
#  2 4 6 7 1 1 3 6 2 6 7 7 4 7 1 2 5 2 2 2 6 3 3 5 4 1 6 2 5 5 0 2 2 3 1 3 2
#  3 2 2 6 6 1 1 3 0 2 1 3 1 3 0 5 5 7 5 5 1 0 6 1 5 3 6 1 1 5 1 7 0 1 6 3 5
#  7 4 3 8 2 7 6 6 4 5 6 6 6 2 1 6 2 5 5 6 4 3 1 1 2 2 6 3 1 8 1 3 2 2 6 5 1
#  2 8 1 1 5 2 2 2 1 4 7 0 0 7 3 0 4 7 6 1 5 5 3 5 0 7 5 5 7 2 1 3 2 6 4 5 5
#  3 6 7 1 6 5 6 2 6 0 6 0 2 1 8 6 4 1 7 5 3 3 7 6 8 8 1 5 4]

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

results_forest=[]
for i in range(2,100):
    forest=RandomForestClassifier(random_state=42,n_estimators=i)
    forest.fit(x_train,y_train)
    results_forest.append(forest.score(x_test,y_test))
    
max_accuracy_forest=max(results_forest)
best_n_est=2+results_forest.index(max(results_forest))
print("Max Accuracy is {:.3f} on test dataset with {} estimators.\n".format(max_accuracy_forest,best_n_est))

plt.plot(numpy.arange(2,100),results_forest)
plt.xlabel("n Estimators")
plt.ylabel("Accuracy")


forest=RandomForestClassifier(random_state=42,n_estimators=best_n_est)
forest.fit(x_train,y_train)
print("Training Score: {:.3f}".format(forest.score(x_train,y_train)))
print("Test score: {:.3f}".format(forest.score(x_test,y_test)))

plot_cnf(forest,x_test,y_test,genres)
# Out:
# Max Accuracy is 0.693 on test dataset with 55 estimators.
#
# Training Score: 0.991
# Test score: 0.693
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# [7 4 6 2 8 3 1 4 5 1 3 1 7 1 3 8 3 0 2 5 6 6 3 1 5 2 3 5 5 2 0 4 1 0 8 3 7
#  1 3 1 7 6 1 5 3 5 5 5 3 1 6 6 8 2 3 6 5 7 7 0 6 1 5 1 3 1 1 1 6 7 3 8 3 4
#  5 2 3 1 2 5 1 5 6 6 4 1 3 5 5 2 2 1 1 1 1 4 3 3 5 6 6 6 5 6 1 6 6 8 1 2 1
